# %% [markdown]
# # basic training & prediction

# %%
import os

import numpy as np

import matplotlib.pyplot as plt

import tensorflow as tf

# %%
import tensorflow_datasets as tfds
tfds.disable_progress_bar()

# %% [markdown]
# tensorflow_datasets 패키지는 pre_defined data를 쉽게 가져올 수 있다.

# %%
(raw_train, raw_validation, raw_test), metadata = tfds.load(
    'cifar10',
    split=['train[:80%]', 'train[80%:90%]', 'train[90%:]'],
    with_info=True,
    as_supervised=True,
)

# %% [markdown]
# tfds.load함수 = data를 다운로드 받고, tf.data.Dataset으로 반환한다. 이 반환된 객체는 데이터 가공하고 모델에 piping하는데 효과적이다.
#
# "cats_vs_dogs"파일을 test(80%), validation(10%), test(10%)로 나누어 사용한다

# %%
# dataset 객체는 (image,label)정보를 포함한다.
print(raw_train)
print(raw_validation)
print(raw_test)
# Out:
# <PrefetchDataset shapes: ((32, 32, 3), ()), types: (tf.uint8, tf.int64)>
# <PrefetchDataset shapes: ((32, 32, 3), ()), types: (tf.uint8, tf.int64)>
# <PrefetchDataset shapes: ((32, 32, 3), ()), types: (tf.uint8, tf.int64)>

# %%
tf.data.DatasetSpec.from_value(raw_train)
# Out:
# DatasetSpec((TensorSpec(shape=(32, 32, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None)), TensorShape([]))

# %%
IMG_SIZE = 160 # All images will be resized to 160x160[input size]

def format_example(image, label):
    image = tf.cast(image, tf.float32)
    image = (image/127.5) - 1
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    return image, label

# %% [markdown]
# tf.cast함수 =  텐서를 새로운 형태로 캐스팅 하는데 사용(float 32bit 까지)
#
# (image/127.5) - 1 = rescale the input channels to a range of (-1,1)

# %%
#map함수를 이용하여 데이터 set의 각 항목에 함수를 적용하는 방법
train = raw_train.map(format_example)
validation = raw_validation.map(format_example)
test = raw_test.map(format_example)

# %%
tf.data.DatasetSpec.from_value(train)
# Out:
# DatasetSpec((TensorSpec(shape=(160, 160, 3), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None)), TensorShape([]))

# %%
BATCH_SIZE = 32
SHUFFLE_BUFFER_SIZE = 1000

# %%
train_batches = train.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
validation_batches = validation.batch(BATCH_SIZE)
test_batches = test.batch(BATCH_SIZE)

# %%
for image_batch, label_batch in train_batches.take(1): pass

image_batch.shape
# Out:
# TensorShape([32, 160, 160, 3])

# %%
IMG_SHAPE = (IMG_SIZE, IMG_SIZE, 3)

# Create the base model from the pre-trained model MobileNet V2
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

# %% [markdown]
# ImageNet에 대해 가중치가 사전로드 된 MobileNet V2 모델을 인스턴스화 한다.
#  - include_top = False 인수를 지정하면 맨 위에 분류 계층이 포함되지 않은 네트워크를로드한다(기능 추출에 이상적으로 하기 위해)

# %%
# 각 160*160*3의 image를 feature block 5*5*1280으로 전환한다.
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (32, 5, 5, 1280)

# %%
base_model.trainable = False
# freezing the convolutional base -> training하면서 weight값이 update되는것을 방지함
base_model.summary()
# Out:
# Model: "mobilenetv2_1.00_160"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 161, 161, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 80, 80, 32)   864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 80, 80, 32)   128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 80, 80, 32)   0           bn_Conv1[0][0]
# ...

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (32, 1280)

# %% [markdown]
# feature block에서 예측하기위해 tf.keras.layers.GlobalAveragePooling2D 레이어를 사용하여 피처를 이미지 당 하나의 1280 요소 벡터로 변환하여 공간 5*5 공간 위치에서 평균을 구한다

# %%
prediction_layer = tf.keras.layers.Dense(10, activation='softmax')
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (32, 10)

# %% [markdown]
# tf.keras.layers.Dense 함수를 적용하여 feature들을 single prediction(이미지당)으로 전환한다.
#
# 양수: 클래스 1을 예측함 / 음수: 클래수 0을 예측함

# %%
model = tf.keras.Sequential([
  base_model,
  global_average_layer,
  prediction_layer
])

# %% [markdown]
# 모델을 하나로 합친다

# %%
#base모델에 feature extractor를 쌓는다
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# mobilenetv2_1.00_160 (Model) (None, 5, 5, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                12810
# ...
# Total params: 2,270,794
# Trainable params: 12,810
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
# mobileNet의 2257984개는 frozen(training 안함)
# dense layer 12810개는 training한다
len(model.trainable_variables)
# Out:
# 2

# %%
# 모델 training한다

initial_epochs = 10
validation_steps=20

loss0,accuracy0 = model.evaluate(validation_batches, steps = validation_steps)
# Out:
# 20/20 [==============================] - 7s 348ms/step - loss: 2.2999 - accuracy: 0.1234

# %%
print("initial loss: {:.2f}".format(loss0))
print("initial accuracy: {:.2f}".format(accuracy0))
# Out:
# initial loss: 2.30
# initial accuracy: 0.12

# %%
history = model.fit(train_batches,
                    epochs=initial_epochs,
                    validation_data=validation_batches)
# Out:
# Epoch 1/10
# 1250/1250 [==============================] - 433s 346ms/step - loss: 1.9889 - accuracy: 0.5643 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 1250/1250 [==============================] - 45s 36ms/step - loss: 1.7929 - accuracy: 0.7341 - val_loss: 1.7510 - val_accuracy: 0.7446
# Epoch 3/10
# 1250/1250 [==============================] - 46s 36ms/step - loss: 1.7504 - accuracy: 0.7559 - val_loss: 1.7343 - val_accuracy: 0.7496
# Epoch 4/10
# 1250/1250 [==============================] - 45s 36ms/step - loss: 1.7318 - accuracy: 0.7657 - val_loss: 1.7336 - val_accuracy: 0.7428
# Epoch 5/10
# 1250/1250 [==============================] - 46s 37ms/step - loss: 1.7208 - accuracy: 0.7728 - val_loss: 1.7316 - val_accuracy: 0.7424
# Epoch 6/10
# 1250/1250 [==============================] - 45s 36ms/step - loss: 1.7105 - accuracy: 0.7780 - val_loss: 1.7272 - val_accuracy: 0.7444
# Epoch 7/10
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')


plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([1.5,4.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# Fine tuning하기

# %%
base_model.trainable = True
# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(base_model.layers))

# Fine-tune from this layer onwards
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable =  False
# Out:
# Number of layers in the base model:  155

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# mobilenetv2_1.00_160 (Model) (None, 5, 5, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                12810
# ...
# Total params: 2,270,794
# Trainable params: 1,875,402
# Non-trainable params: 395,392
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 58

# %%
fine_tune_epochs = 10
total_epochs =  initial_epochs + fine_tune_epochs

history_fine = model.fit(train_batches,
                         epochs=total_epochs,
                         initial_epoch =  history.epoch[-1],
                         validation_data=validation_batches)
# Out:
# Epoch 10/20
# 1250/1250 [==============================] - 59s 47ms/step - loss: 1.6321 - accuracy: 0.8320 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 1250/1250 [==============================] - 53s 42ms/step - loss: 1.5765 - accuracy: 0.8859 - val_loss: 1.7107 - val_accuracy: 0.7560
# Epoch 12/20
# 1250/1250 [==============================] - 52s 42ms/step - loss: 1.5572 - accuracy: 0.9044 - val_loss: 1.7770 - val_accuracy: 0.6818
# Epoch 13/20
# 1250/1250 [==============================] - 53s 42ms/step - loss: 1.5409 - accuracy: 0.9208 - val_loss: 1.7034 - val_accuracy: 0.7586
# Epoch 14/20
# 1250/1250 [==============================] - 53s 42ms/step - loss: 1.5328 - accuracy: 0.9283 - val_loss: 1.6862 - val_accuracy: 0.7770
# Epoch 15/20
# 1250/1250 [==============================] - 53s 43ms/step - loss: 1.5226 - accuracy: 0.9389 - val_loss: 1.6390 - val_accuracy: 0.8224
# Epoch 16/20
# ...

# %% [markdown]
# https://jeinalog.tistory.com/13

# %%
acc += history_fine.history['accuracy']
val_acc += history_fine.history['val_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

print("acc: ",acc[-1]," loss: ",loss[-1])
# Out:
# acc:  0.960825  loss:  1.501225747489929

# %%
import tempfile
import os

import tensorflow as tf
import numpy as np

from tensorflow import keras

# %%
_, keras_file = tempfile.mkstemp('.h5')
tf.keras.models.save_model(model, keras_file, include_optimizer=False)
print('Saved baseline mobileNetV2 model to:', keras_file)
# Out:
# Saved baseline mobileNetV2 model to: /tmp/tmpsxy5b8dv.h5

# %%
def get_gzipped_model_size(file):
  # Returns size of gzipped model, in bytes.
    import os
    import zipfile

    _, zipped_file = tempfile.mkstemp('.zip')
    with zipfile.ZipFile(zipped_file, 'w', compression=zipfile.ZIP_DEFLATED) as f:
        f.write(file)

    return os.path.getsize(zipped_file)

# %%
print("Keras model acc: ",acc[-1]," loss: ",loss[-1])
# Out:
# Keras model acc:  0.960825  loss:  1.501225747489929

# %% [markdown]
# # Pruning only

# %%
import tensorflow_model_optimization as tfmot
from tensorflow import keras
prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude

# %%
batch_size = 32
epochs = 70
validation_split = 0.1

# %%
num_images = 50000 * (1 - validation_split)
end_step = np.ceil(num_images / batch_size).astype(np.int32) * epochs

end_step
# Out:
# 98490

# %%
pruning_params = {
      'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.50,
                                                               final_sparsity=0.80,
                                                               begin_step=0,
                                                               end_step=end_step,
                                                              frequency=100)
}

# %%
import re
model_for_pruning = tf.keras.Sequential()
for layer in model.layers:
    if(re.match(r"conv_pw_\d+$", layer.name)):
         model_for_pruning.add(sparsity.prune_low_magnitude(
            layer,
            pruning_schedule,
            block_size=(1,1)
         ))
    else:
        model_for_pruning.add(layer)

# %%
model_for_pruning.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model_for_pruning.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# mobilenetv2_1.00_160 (Model) (None, 5, 5, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                12810
# ...
# Total params: 2,270,794
# Trainable params: 1,875,402
# Non-trainable params: 395,392
# _________________________________________________________________

# %%
logdir = tempfile.mkdtemp()

callbacks = [
  tfmot.sparsity.keras.UpdatePruningStep(),
  tfmot.sparsity.keras.PruningSummaries(log_dir=logdir),
]

# %%
history_fine = model_for_pruning.fit(train_batches, epochs=epochs, validation_data=validation_batches, callbacks=callbacks)
# Out:
# Epoch 1/30
#       1/Unknown - 3s 3s/step - loss: 1.5326 - accuracy: 0.9062WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.134900). Check your callbacks.
# WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.134900). Check your callbacks.
# 1250/1250 [==============================] - 60s 48ms/step - loss: 1.7895 - accuracy: 0.6707 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 1250/1250 [==============================] - 53s 43ms/step - loss: 1.7461 - accuracy: 0.7156 - val_loss: 2.0815 - val_accuracy: 0.3770
# Epoch 3/30
# 1250/1250 [==============================] - 54s 43ms/step - loss: 1.7177 - accuracy: 0.7444 - val_loss: 2.1404 - val_accuracy: 0.3212
# Epoch 4/30
# 1250/1250 [==============================] - 54s 43ms/step - loss: 1.6948 - accuracy: 0.7647 - val_loss: 1.9250 - val_accuracy: 0.5374
# Epoch 5/30
# ...

# %%
acc += history_fine.history['accuracy']
val_acc += history_fine.history['val_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

print("acc: ",acc[-1]," loss: ",loss[-1])
# Out:
# acc:  0.89365  loss:  1.566886892414093

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([0.0, 1.5])
plt.plot([initial_epochs-1,initial_epochs-1],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.ylim([1.0, 3.0])
plt.plot([initial_epochs-1,initial_epochs-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
model_for_export = tfmot.sparsity.keras.strip_pruning(model_for_pruning)

_, pruned_keras_file = tempfile.mkstemp('.h5')
tf.keras.models.save_model(model_for_export, pruned_keras_file, include_optimizer=False)
print('Saved pruned Keras model to:', pruned_keras_file)
# Out:
# Saved pruned Keras model to: /tmp/tmp3ocb5o56.h5

# %%
print("Size of gzipped baseline basic Keras model: %.2f bytes" % (get_gzipped_model_size(keras_file)))
print("Size of gzipped pruned Keras model: %.2f bytes" % (get_gzipped_model_size(pruned_keras_file)))
# Out:
# Size of gzipped baseline basic Keras model: 8466732.00 bytes
# Size of gzipped pruned Keras model: 8463759.00 bytes
